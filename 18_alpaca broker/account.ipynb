# %%
from alpaca.trading.client import TradingClient
api_key='PKSFPBOGXCM4LWVR3T2JHYHAIU'
secret_key='7JFMkCuQ98bVAJHDeyo4bw3RGSic7CmpmGdUk4cntPv'
trading_client = TradingClient(api_key, secret_key)

account = trading_client.get_account()
account
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA32II6CTZQA',
#     'accrued_fees': '0',
#     'buying_power': '710923.8',
#     'cash': '21215.93',
#     'created_at': datetime.datetime(2024, 8, 24, 9, 13, 29, 133143, tzinfo=TzInfo(0)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '710923.8',
#     'equity': '871226.21',
#     'id': UUID('28959f70-ced0-4150-a908-c1d2ef1a475a'),
#     'initial_margin': '112837.31',
#     'last_equity': '878905.977195241416',
#     'last_maintenance_margin': '67786.83',
#     'long_market_value': '850696.66',
#     'maintenance_margin': '67786.83',
#     'multiplier': '4',
#     'non_marginable_buying_power': '132680.47',
#     'options_approved_level': 3,
#     'options_buying_power': '132680.47',
#     'options_trading_level': 3,
#     'pattern_day_trader': True,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '871226.21',
#     'regt_buying_power': '265360.95',
#     'short_market_value': '-686.38',
#     'shorting_enabled': True,
#     'sma': '248250.44',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
pos=trading_client.get_all_positions()
pos
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('03fb07bb-5db1-4077-8dea-5d711b272625'),
#      'asset_marginable': True,
#      'avg_entry_price': '212.99',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '212.99',
#      'current_price': '424.1',
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'lastday_price': '424.1',
#      'market_value': '424.1',
#      'qty': '1',
#      'qty_available': '1',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'AMD',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '211.11',
#      'unrealized_plpc': '0.99117',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('f801f835-bfe6-4a9d-a6b1-ccbb84bfd75f'),
#      'asset_marginable': True,
#      'avg_entry_price': '218.25',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '-218.25',
#      'current_price': '264.14',
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'lastday_price': '264.14',
#      'market_value': '-264.14',
#      'qty': '-1',
#      'qty_available': '-1',
#      'side': <PositionSide.SHORT: 'short'>,
#      'swap_rate': None,
#      'symbol': 'AMZN',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '-45.89',
#      'unrealized_plpc': '-0.21026',
#      'usd': None},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('64bbff51-59d6-4b3c-9351-13ad85e3c752'),
#      'asset_marginable': False,
#      'avg_entry_price': '97984.267246233',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.0034',
#      'cost_basis': '781914.452331',
#      'current_price': '78136.16',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '77871.78',
#      'market_value': '623526.556566',
#      'qty': '7.979999997',
#      'qty_available': '7.979999997',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'BTCUSD',
#      'unrealized_intraday_pl': '2109.7524',
#      'unrealized_intraday_plpc': '0.0034',
#      'unrealized_pl': '-158387.895765',
#      'unrealized_plpc': '-0.20256',
#      'usd': None},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('a3ba8ac0-166d-460b-b17a-1f035622dd47'),
#      'asset_marginable': False,
#      'avg_entry_price': '0.325',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.01753',
#      'cost_basis': '0.324285',
#      'current_price': '0.1103',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '0.1084',
#      'market_value': '0.110057',
#      'qty': '0.9978',
#      'qty_available': '0.9978',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'DOGEUSD',
#      'unrealized_intraday_pl': '0.001895',
#      'unrealized_intraday_plpc': '0.01752',
#      'unrealized_pl': '-0.214228',
#      'unrealized_plpc': '-0.66062',
#      'usd': None},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('35f33a69-f5d6-4dc9-b158-4485e5e92e4b'),
#      'asset_marginable': False,
#      'avg_entry_price': '3834.58',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.00792',
#      'cost_basis': '3824.99355',
#      'current_price': '2187.227',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '2170.03790385',
#      'market_value': '2181.758933',
#      'qty': '0.9975',
#      'qty_available': '0.9975',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'ETHUSD',
#      'unrealized_intraday_pl': '17.146124',
#      'unrealized_intraday_plpc': '0.00792',
#      'unrealized_pl': '-1643.234617',
#      'unrealized_plpc': '-0.4296',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('e3047683-637a-4fb2-b71d-805cd6fec95d'),
#      'asset_marginable': True,
#      'avg_entry_price': '289.435',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '578.87',
#      'current_price': '297.81',
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'lastday_price': '297.81',
#      'market_value': '595.62',
#      'qty': '2',
#      'qty_available': '2',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'JPM',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '16.75',
#      'unrealized_plpc': '0.02894',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'asset_marginable': True,
#      'avg_entry_price': '604',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '183012',
#      'current_price': '739.17',
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'lastday_price': '739.17',
#      'market_value': '223968.51',
#      'qty': '303',
#      'qty_available': '303',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'SPY',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '40956.51',
#      'unrealized_plpc': '0.22379',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('8ccae427-5dd0-45b3-b5fe-7ba5e422c766'),
#      'asset_marginable': True,
#      'avg_entry_price': '421.98',
#      'avg_entry_swap_rate': None,
#      'change_today': '0',
#      'cost_basis': '-421.98',
#      'current_price': '422.24',
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'lastday_price': '422.24',
#      'market_value': '-422.24',
#      'qty': '-1',
#      'qty_available': '0',
#      'side': <PositionSide.SHORT: 'short'>,
#      'swap_rate': None,
#      'symbol': 'TSLA',
#      'unrealized_intraday_pl': '0',
#      'unrealized_intraday_plpc': '0',
#      'unrealized_pl': '-0.26',
#      'unrealized_plpc': '-0.00062',
#      'usd': None}]

# %%
import pandas as pd
pos_list=[]
for p in pos:
    pos_list.append(dict(p))
df=pd.DataFrame(pos_list)
df
# Out:
#                                asset_id   symbol              exchange  \
# 0  03fb07bb-5db1-4077-8dea-5d711b272625      AMD  AssetExchange.NASDAQ
# 1  f801f835-bfe6-4a9d-a6b1-ccbb84bfd75f     AMZN  AssetExchange.NASDAQ
# 2  64bbff51-59d6-4b3c-9351-13ad85e3c752   BTCUSD  AssetExchange.CRYPTO
# 3  a3ba8ac0-166d-460b-b17a-1f035622dd47  DOGEUSD  AssetExchange.CRYPTO
# 4  35f33a69-f5d6-4dc9-b158-4485e5e92e4b   ETHUSD  AssetExchange.CRYPTO
# 5  e3047683-637a-4fb2-b71d-805cd6fec95d      JPM    AssetExchange.NYSE
# 6  b28f4066-5c6d-479b-a2af-85dc1a8f16fb      SPY    AssetExchange.ARCA
# 7  8ccae427-5dd0-45b3-b5fe-7ba5e422c766     TSLA  AssetExchange.NASDAQ
#
#             asset_class  asset_marginable  avg_entry_price          qty  \
# 0  AssetClass.US_EQUITY              True           212.99            1
# 1  AssetClass.US_EQUITY              True           218.25           -1
# 2     AssetClass.CRYPTO             False  97984.267246233  7.979999997
# 3     AssetClass.CRYPTO             False            0.325       0.9978
# 4     AssetClass.CRYPTO             False          3834.58       0.9975
# 5  AssetClass.US_EQUITY              True          289.435            2
# 6  AssetClass.US_EQUITY              True              604          303
# 7  AssetClass.US_EQUITY              True           421.98           -1
#
#                  side   market_value     cost_basis  ... unrealized_plpc  \
# 0   PositionSide.LONG          424.1         212.99  ...         0.99117
# 1  PositionSide.SHORT        -264.14        -218.25  ...        -0.21026
# 2   PositionSide.LONG  623526.556566  781914.452331  ...        -0.20256
# 3   PositionSide.LONG       0.110057       0.324285  ...        -0.66062
# 4   PositionSide.LONG    2181.758933     3824.99355  ...         -0.4296
# 5   PositionSide.LONG         595.62         578.87  ...         0.02894
# 6   PositionSide.LONG      223968.51         183012  ...         0.22379
# 7  PositionSide.SHORT        -422.24        -421.98  ...        -0.00062
#
#   unrealized_intraday_pl unrealized_intraday_plpc current_price  \
# 0                      0                        0         424.1
# 1                      0                        0        264.14
# 2              2109.7524                   0.0034      78136.16
# 3               0.001895                  0.01752        0.1103
# 4              17.146124                  0.00792      2187.227
# 5                      0                        0        297.81
# 6                      0                        0        739.17
# 7                      0                        0        422.24
#
#    lastday_price change_today swap_rate avg_entry_swap_rate   usd  \
# 0          424.1            0      None                None  None
# 1         264.14            0      None                None  None
# 2       77871.78       0.0034      None                None  None
# 3         0.1084      0.01753      None                None  None
# 4  2170.03790385      0.00792      None                None  None
# 5         297.81            0      None                None  None
# 6         739.17            0      None                None  None
# 7         422.24            0      None                None  None
#
#   qty_available
# 0             1
# 1            -1
# 2   7.979999997
# 3        0.9978
# 4        0.9975
# 5             2
# 6           303
# 7             0
#
# [8 rows x 21 columns]

# %%
ord=trading_client.get_orders()
ord_list=[]
for o in ord:
    ord_list.append(dict(o))
df=pd.DataFrame(ord_list)
df.to_csv('orders.csv', index=False)
