# %%
from alpaca.trading.client import TradingClient
api_key='PKSFPBOGXCM4LWVR3T2JHYHAIU'
secret_key='7JFMkCuQ98bVAJHDeyo4bw3RGSic7CmpmGdUk4cntPv'
trading_client = TradingClient(api_key, secret_key)

account = trading_client.get_account()
account
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA32II6CTZQA',
#     'accrued_fees': '0',
#     'buying_power': '709638.8',
#     'cash': '21215.93',
#     'created_at': datetime.datetime(2024, 8, 24, 9, 13, 29, 133143, tzinfo=TzInfo(0)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '709638.8',
#     'equity': '892627.26',
#     'id': UUID('28959f70-ced0-4150-a908-c1d2ef1a475a'),
#     'initial_margin': '112629.64',
#     'last_equity': '889501.86218701233',
#     'last_maintenance_margin': '67663.45',
#     'long_market_value': '872112.36',
#     'maintenance_margin': '67663.45',
#     'multiplier': '4',
#     'non_marginable_buying_power': '130443.51',
#     'options_approved_level': 3,
#     'options_buying_power': '132443.51',
#     'options_trading_level': 3,
#     'pattern_day_trader': True,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '892627.26',
#     'regt_buying_power': '264887.02',
#     'short_market_value': '-701.03',
#     'shorting_enabled': True,
#     'sma': '243222.71',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}
