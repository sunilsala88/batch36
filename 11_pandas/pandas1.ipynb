# %%
# !pip3 install pandas
# Out:
# ...
#   Using cached pandas-3.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
# Using cached pandas-3.0.1-cp313-cp313-macosx_11_0_arm64.whl (9.9 MB)
# ...

# %%
import pandas as pd
a=[[1,2,3],[4,5,6],[7,8,9]]
df1=pd.DataFrame(a,index=['row1','row2','row3'],columns=['col1','col2','col3'])
df1
# Out:
#       col1  col2  col3
# row1     1     2     3
# row2     4     5     6
# row3     7     8     9

# %%
import numpy as np
a=[[1,2,3],[4,5,6],[7,8,9]]
np1=np.array(a)
print(np1)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
df2=pd.DataFrame(np1,index=['r1','r2','r3'],columns=['c1','c2','c3'])
df2
# Out:
#     c1  c2  c3
# r1   1   2   3
# r2   4   5   6
# r3   7   8   9

# %%
d1={'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'City':['New York','Los Angeles','Chicago']}
df3=pd.DataFrame(d1)
df3
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
l1=[{'Name':'Alice','Age':25,'City':'New York'},
    {'Name':'Bob','Age':30,'City':'Los Angeles'},
    {'Name':'Charlie','Age':35,'City':'Chicago'}]
df4=pd.DataFrame(l1)
df4
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df=pd.read_csv(r'/Users/algo trading 2026/batch36/11_pandas/sp500.csv')
df
# Out:
#                            Name                  Sector   Price    EPS
# 0                     Apple Inc  Information Technology  170.12   9.20
# 1                    Abbvie Inc             Health Care   93.29   5.31
# 2           Abbott Laboratories             Health Care   55.28   2.41
# 3                 Accenture Plc  Information Technology  145.30    NaN
# 4                  Allergan Plc             Health Care  171.81  15.42
# ..                          ...                     ...     ...    ...
# 97   Verizon Communications Inc      Telecommunications   45.85   3.75
# 98     Walgreens Boots Alliance        Consumer Staples   70.25   5.10
# 99        Wells Fargo & Company              Financials   54.02   4.14
# 100             Wal-Mart Stores        Consumer Staples   96.08   4.36
# 101            Exxon Mobil Corp                  Energy   80.31   3.56
#
# [102 rows x 4 columns]

# %%
df7=pd.read_excel(r'/Users/algo trading 2026/batch36/11_pandas/e500.xlsx')
df7
# Out:
#      Unnamed: 0                        Name                  Sector   Price  \
# 0             0                   Apple Inc  Information Technology  170.12
# 1             1                  Abbvie Inc             Health Care   93.29
# 2             2         Abbott Laboratories             Health Care   55.28
# 3             3               Accenture Plc  Information Technology  145.30
# 4             4                Allergan Plc             Health Care  171.81
# ..          ...                         ...                     ...     ...
# 97           97  Verizon Communications Inc      Telecommunications   45.85
# 98           98    Walgreens Boots Alliance        Consumer Staples   70.25
# 99           99       Wells Fargo & Company              Financials   54.02
# 100         100             Wal-Mart Stores        Consumer Staples   96.08
# 101         101            Exxon Mobil Corp                  Energy   80.31
#
#        EPS
# 0     9.20
# 1     5.31
# 2     2.41
# ...

# %%
# !pip3 install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...

# %%
from io import StringIO
import ssl
import urllib.request
import certifi

url = 'https://www.screener.in/screens/281185/nifty-50/'
ssl_context = ssl.create_default_context(cafile=certifi.where())

with urllib.request.urlopen(url, context=ssl_context) as response:
    html = response.read().decode('utf-8')

df9 = pd.read_html(StringIO(html))
df9[0]
# Out:
#     S.No.                 Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0      1.  Reliance Industries   1380.70  24.35       1868897.82        0.40
# 1      2.            HDFC Bank    817.00  16.88       1257769.36        1.35
# 2      3.        Bharti Airtel   1803.40  33.57       1028603.19        0.89
# 3      4.                  SBI   1047.00  11.92        966312.09        1.52
# 4      5.           ICICI Bank   1254.80  16.97        898486.45        0.88
# 5      6.                  TCS   2410.50  17.06        871979.34        2.49
# 6      7.        Bajaj Finance    855.05  29.20        531776.06        0.51
# 7      8.       Hind. Unilever   2160.00  46.53        507856.32        1.99
# 8      9.              Infosys   1248.30  17.54        506214.48        3.44
# 9     10.       Life Insurance    772.70   9.22        488824.61        1.55
# 10    11.      Larsen & Toubro   3439.00  27.72        472888.46        0.99
# ...

# %%
# !pip3 install lxml
# Out:
# ...
#   Using cached lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Using cached lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl (8.6 MB)
# ...

# %%
# !pip3 install certifi
# Out:
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=102, step=1)

# %%
list(df.columns)
# Out:
# ['Name', 'Sector', 'Price', 'EPS']

# %%
df.shape
# Out:
# (102, 4)

# %%
df.head(10)
# Out:
#                            Name                  Sector    Price    EPS
# 0                     Apple Inc  Information Technology   170.12   9.20
# 1                    Abbvie Inc             Health Care    93.29   5.31
# 2           Abbott Laboratories             Health Care    55.28   2.41
# 3                 Accenture Plc  Information Technology   145.30    NaN
# 4                  Allergan Plc             Health Care   171.81  15.42
# 5  American International Group              Financials    59.50   2.51
# 6                 Allstate Corp              Financials   100.50   6.79
# 7                         Amgen             Health Care   168.93  12.58
# 8               Amazon.Com Inc.  Consumer Discretionary  1126.82   3.94
# 9      American Express Company              Financials    93.92   5.22

# %%
df.tail(10)
# Out:
#                            Name                  Sector   Price   EPS
# 92           Union Pacific Corp             Industrials  115.58  5.66
# 93        United Parcel Service             Industrials  113.20  5.98
# 94                 U.S. Bancorp              Financials   51.88  3.37
# 95     United Technologies Corp             Industrials  117.05  6.62
# 96                     Visa Inc  Information Technology  110.27  3.48
# 97   Verizon Communications Inc      Telecommunications   45.85  3.75
# 98     Walgreens Boots Alliance        Consumer Staples   70.25  5.10
# 99        Wells Fargo & Company              Financials   54.02  4.14
# 100             Wal-Mart Stores        Consumer Staples   96.08  4.36
# 101            Exxon Mobil Corp                  Energy   80.31  3.56

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    102 non-null    str
#  1   Sector  102 non-null    str
#  2   Price   102 non-null    float64
#  3   EPS     101 non-null    float64
# dtypes: float64(2), str(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#              Price        EPS
# count   102.000000  101.00000
# mean    150.500686    6.49099
# std     240.768463    8.62033
# min      12.110000    0.02000
# 25%      54.335000    2.87000
# 50%      88.295000    4.36000
# 75%     151.032500    6.62000
# max    1762.230000   74.45000

# %%
#series->single column of data
df['Price']
# Out:
# 0      170.12
# 1       93.29
# 2       55.28
# 3      145.30
# 4      171.81
#         ...
# 97      45.85
# 98      70.25
# 99      54.02
# 100     96.08
# 101     80.31
# Name: Price, Length: 102, dtype: float64

# %%
df.EPS
# Out:
# 0       9.20
# 1       5.31
# 2       2.41
# 3        NaN
# 4      15.42
#        ...
# 97      3.75
# 98      5.10
# 99      4.14
# 100     4.36
# 101     3.56
# Name: EPS, Length: 102, dtype: float64

# %%
df['new']=df['Price']+df['EPS']

# %%
df['new']=df['Price']*2

# %%
df[df['Price']>200]
# Out:
#                       Name                  Sector    Price    EPS      new
# 8          Amazon.Com Inc.  Consumer Discretionary  1126.82   3.94  2253.64
# 10          Boeing Company             Industrials   265.04   9.75   530.08
# 12              Biogen Inc             Health Care   311.92  21.59   623.84
# 14               Blackrock              Financials   474.05  21.55   948.10
# 20    Charter Communicatio  Consumer Discretionary   346.20   1.61   692.40
# 37              Fedex Corp             Industrials   217.75  11.91   435.50
# 44        Alphabet Class C  Information Technology  1018.48  29.87  2036.96
# 45        Alphabet Class A  Information Technology  1034.09  29.87  2068.18
# 46     Goldman Sachs Group              Financials   238.05  19.20   476.10
# 58    Lockheed Martin Corp             Industrials   312.93  12.72   625.86
# 65              3M Company             Industrials   232.49   8.95   464.98
# ...

# %%
df[df['EPS']>10]
# Out:
#                                Name                  Sector    Price    EPS  \
# 4                      Allergan Plc             Health Care   171.81  15.42
# 7                             Amgen             Health Care   168.93  12.58
# 12                       Biogen Inc             Health Care   311.92  21.59
# 14                        Blackrock              Financials   474.05  21.55
# 37                       Fedex Corp             Industrials   217.75  11.91
# 40            General Dynamics Corp             Industrials   198.70  10.07
# 44                 Alphabet Class C  Information Technology  1018.48  29.87
# 45                 Alphabet Class A  Information Technology  1034.09  29.87
# 46              Goldman Sachs Group              Financials   238.05  19.20
# 50  International Business Machines  Information Technology   151.40  13.66
# 58             Lockheed Martin Corp             Industrials   312.93  12.72
# ...
