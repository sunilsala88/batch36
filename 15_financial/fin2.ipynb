# %%
# !pip install finvizfinance
# Out:
# ...
#   Using cached finvizfinance-1.3.0-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached finvizfinance-1.3.0-py3-none-any.whl (44 kB)
# ...

# %%
from finvizfinance.quote import finvizfinance

stock = finvizfinance('tsla')

# %%
stock.ticker_fundament().get('Beta')
# Out:
# '1.93'

# %%
stocks=['AMZN','TSLA','GOOG','MSFT']
betas={}
for s in stocks:
    stock = finvizfinance(s)
    betas[s]=float(stock.ticker_fundament().get('Beta'))
print(betas)
# Out:
# {'AMZN': 1.36, 'TSLA': 1.93, 'GOOG': 1.1, 'MSFT': 1.1}

# %%
temp=list(betas.values())
i=temp.index(max(temp))
list(betas.keys())[i]
# Out:
# 'TSLA'
