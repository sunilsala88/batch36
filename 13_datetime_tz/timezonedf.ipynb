# %%
# !pip3 install yfinance
# Out:
# ...
#   Using cached multitasking-0.0.12-py3-none-any.whl
# ...
#   Using cached frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# ...
#   Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# ...
#   Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# ...
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# ...
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Using cached frozendict-2.4.7-py3-none-any.whl (16 kB)
# ...
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# ...

# %%
import yfinance as yf
df=yf.download('AAPL',period='1y',interval='1h',multi_level_index=False)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Close        High         Low        Open  \
# Datetime
# 2025-03-28 13:30:00+00:00  219.910004  223.800003  219.695007  221.649002
# 2025-03-28 14:30:00+00:00  219.979996  220.649994  219.169998  219.889999
# 2025-03-28 15:30:00+00:00  218.690002  220.220001  218.350006  219.891098
# 2025-03-28 16:30:00+00:00  218.490005  219.119995  218.210007  218.669998
# 2025-03-28 17:30:00+00:00  219.050003  219.166504  218.179993  218.500000
# ...                               ...         ...         ...         ...
# 2026-03-27 15:30:00+00:00  251.779999  253.240005  251.690002  252.619995
# 2026-03-27 16:30:00+00:00  250.410004  252.759995  250.369995  251.774994
# 2026-03-27 17:30:00+00:00  249.384995  250.580002  248.634995  250.410004
# 2026-03-27 18:30:00+00:00  248.409897  249.520004  248.250000  249.419998
# 2026-03-27 19:30:00+00:00  248.619995  249.369995  248.070007  248.410004
#
# ...

# %%
df=df.reset_index()
df
# Out:
#                       Datetime       Close        High         Low  \
# 0    2025-03-28 13:30:00+00:00  219.910004  223.800003  219.695007
# 1    2025-03-28 14:30:00+00:00  219.979996  220.649994  219.169998
# 2    2025-03-28 15:30:00+00:00  218.690002  220.220001  218.350006
# 3    2025-03-28 16:30:00+00:00  218.490005  219.119995  218.210007
# 4    2025-03-28 17:30:00+00:00  219.050003  219.166504  218.179993
# ...                        ...         ...         ...         ...
# 1731 2026-03-27 15:30:00+00:00  251.779999  253.240005  251.690002
# 1732 2026-03-27 16:30:00+00:00  250.410004  252.759995  250.369995
# 1733 2026-03-27 17:30:00+00:00  249.384995  250.580002  248.634995
# 1734 2026-03-27 18:30:00+00:00  248.409897  249.520004  248.250000
# 1735 2026-03-27 19:30:00+00:00  248.619995  249.369995  248.070007
#
#             Open   Volume
# 0     221.649002  8900229
# 1     219.889999  4819013
# 2     219.891098  3075097
# 3     218.669998  3059478
# ...

# %%
df['Datetime'].dt.tz_localize(None)
# Out:
# 0      2025-03-28 13:30:00
# 1      2025-03-28 14:30:00
# 2      2025-03-28 15:30:00
# 3      2025-03-28 16:30:00
# 4      2025-03-28 17:30:00
#                ...
# 1731   2026-03-27 15:30:00
# 1732   2026-03-27 16:30:00
# 1733   2026-03-27 17:30:00
# 1734   2026-03-27 18:30:00
# 1735   2026-03-27 19:30:00
# Name: Datetime, Length: 1736, dtype: datetime64[s]

# %%
df['Datetime'].dt.tz_convert("America/New_York")
# Out:
# 0      2025-03-28 09:30:00-04:00
# 1      2025-03-28 10:30:00-04:00
# 2      2025-03-28 11:30:00-04:00
# 3      2025-03-28 12:30:00-04:00
# 4      2025-03-28 13:30:00-04:00
#                   ...
# 1731   2026-03-27 11:30:00-04:00
# 1732   2026-03-27 12:30:00-04:00
# 1733   2026-03-27 13:30:00-04:00
# 1734   2026-03-27 14:30:00-04:00
# 1735   2026-03-27 15:30:00-04:00
# Name: Datetime, Length: 1736, dtype: datetime64[s, America/New_York]

# %%
import pandas as pd
data=pd.read_csv('/Users/algo trading 2026/batch36/13_datetime_tz/candle.csv')
data
# Out:
#                        Datetime       Close        High         Low  \
# 0     2026-01-26 14:30:00+00:00  442.665009  445.029999  442.130005
# 1     2026-01-26 14:31:00+00:00  443.399994  443.529999  442.269989
# 2     2026-01-26 14:32:00+00:00  442.079895  443.399994  441.470001
# 3     2026-01-26 14:33:00+00:00  441.380005  442.750000  441.380005
# 4     2026-01-26 14:34:00+00:00  439.649994  441.378387  439.600006
# ...                         ...         ...         ...         ...
# 1930  2026-01-30 20:55:00+00:00  432.059998  432.609985  430.250000
# 1931  2026-01-30 20:56:00+00:00  430.798615  432.100006  430.519989
# 1932  2026-01-30 20:57:00+00:00  430.739990  430.869995  430.399994
# 1933  2026-01-30 20:58:00+00:00  430.600006  430.850006  430.399994
# 1934  2026-01-30 20:59:00+00:00  430.436005  430.920013  430.100006
#
#             Open   Volume
# 0     445.029999  1121872
# 1     442.665009   268066
# 2     443.364990   292367
# 3     442.029999   213710
# ...

# %%
data['Datetime']=pd.to_datetime(data['Datetime'],unit='s')
data
# Out:
#                       Datetime       Close        High         Low  \
# 0    2026-01-26 14:30:00+00:00  442.665009  445.029999  442.130005
# 1    2026-01-26 14:31:00+00:00  443.399994  443.529999  442.269989
# 2    2026-01-26 14:32:00+00:00  442.079895  443.399994  441.470001
# 3    2026-01-26 14:33:00+00:00  441.380005  442.750000  441.380005
# 4    2026-01-26 14:34:00+00:00  439.649994  441.378387  439.600006
# ...                        ...         ...         ...         ...
# 1930 2026-01-30 20:55:00+00:00  432.059998  432.609985  430.250000
# 1931 2026-01-30 20:56:00+00:00  430.798615  432.100006  430.519989
# 1932 2026-01-30 20:57:00+00:00  430.739990  430.869995  430.399994
# 1933 2026-01-30 20:58:00+00:00  430.600006  430.850006  430.399994
# 1934 2026-01-30 20:59:00+00:00  430.436005  430.920013  430.100006
#
#             Open   Volume
# 0     445.029999  1121872
# 1     442.665009   268066
# 2     443.364990   292367
# 3     442.029999   213710
# ...

# %%
data['Datetime'].dt.tz_convert("Asia/Kolkata").dt.tz_localize(None)
# Out:
# 0      2026-01-26 20:00:00
# 1      2026-01-26 20:01:00
# 2      2026-01-26 20:02:00
# 3      2026-01-26 20:03:00
# 4      2026-01-26 20:04:00
#                ...
# 1930   2026-01-31 02:25:00
# 1931   2026-01-31 02:26:00
# 1932   2026-01-31 02:27:00
# 1933   2026-01-31 02:28:00
# 1934   2026-01-31 02:29:00
# Name: Datetime, Length: 1935, dtype: datetime64[us]
